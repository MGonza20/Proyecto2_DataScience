# %% [markdown]
# Wenas

# %%
import pandas as pd
import zipfile
import os

# %%
dataset_proyect2 = pd.read_csv("./drive/Shareddrives/Data Science Proyecto 2/DataSets/train.csv")

# %%
dataset_proyect2
# Out:
#                               filename growth_stage damage  extent  season
# 0       L398F01276C01S07896Rp26856.jpg            F     DR       0  LR2021
# 1       L355F02268C02S08916Rp30595.jpg            F     DR       0  LR2021
# 2       L134F00879C39S14248Rp42482.jpg            F     DR      10  SR2021
# 3      L1095F01359C01S08260Rp24587.jpg            F     DR      10  LR2021
# 4       L134F00777C39S14171Rp45993.jpg            F     DR      10  SR2021
# ...                                ...          ...    ...     ...     ...
# 26101   L354F03913C01S09853Rp22354.jpg            V     WN      20  LR2021
# 26102   L371F00110C01S06849Rp17916.jpg            V     WN      20  LR2021
# 26103  L1115F00437C39S12162Rp34884.jpg            V     WN      20  SR2021
# 26104  L1136F03296C01S09382Rp19244.jpg            V     WN      20  LR2021
# 26105  L1130F00057C01S08015Rp15970.jpg            V     WN      90  LR2021
#
# [26106 rows x 5 columns]

# %%
ruta_zip = './drive/Shareddrives/Data Science Proyecto 2/DataSets/test.zip'

ruta_salida = './drive/Shareddrives/Data Science Proyecto 2/DataSets/test'

os.makedirs(ruta_salida, exist_ok=True)

with zipfile.ZipFile(ruta_zip, 'r') as zip_ref:
    zip_ref.extractall(ruta_salida)

print(f"Imágenes extraídas en: {ruta_salida}")
# Out:
# Imágenes extraídas en: ./drive/Shareddrives/Data Science Proyecto 2/DataSets/test

# %%
ruta_zip = './drive/Shareddrives/Data Science Proyecto 2/DataSets/train.zip'

ruta_salida = './drive/Shareddrives/Data Science Proyecto 2/DataSets/train'

os.makedirs(ruta_salida, exist_ok=True)

with zipfile.ZipFile(ruta_zip, 'r') as zip_ref:
    zip_ref.extractall(ruta_salida)

print(f"Imágenes extraídas en: {ruta_salida}")
# Out:
# Imágenes extraídas en: ./drive/Shareddrives/Data Science Proyecto 2/DataSets/train
